# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/amey05081999/Flyrank-Internship-Amey-Naik/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification *

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# *  2. F1-score. The dataset is likely imbalanced because only a minority of pages experience major declines. Accuracy could be misleading by favoring the majority class, whereas the F1-score balances precision (avoiding unnecessary interventions) and recall (identifying pages that truly need attention). This makes it the most appropriate evaluation metric for the business objective..*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *F1-score. The dataset is likely imbalanced because only a minority of pages experience major declines. Accuracy could be misleading by favoring the majority class, whereas the F1-score balances precision (avoiding unnecessary interventions) and recall (identifying pages that truly need attention). This makes it the most appropriate evaluation metric for the business objective.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *One row of the DataFrame represents a single content page (URL/Page ID) at a specific observation period with features such as impressions, clicks, CTR, ranking position, traffic trend, and engagement metrics. Each row is treated as one independent observation for model training.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *Organic search performance depends on many interacting variables including CTR, rankings, historical trends, user engagement, seasonality, and content quality. There is no single threshold (e.g., CTR < 2%) that consistently predicts future decline. Machine learning can learn complex, non-linear relationships between multiple features and generalize to unseen pages, whereas manually defined rules cannot capture these interactions effectively*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
